# %%
import sys
import os

# Add the current working directory to sys.path
sys.path.append(r'C:\Users\LENOVO\Desktop\desktop docs\SUPERVISEDLEARNING')

# Now import the module
from classs import NN_model
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 8
#       5 sys.path.append(r'C:\Users\LENOVO\Desktop\desktop docs\SUPERVISEDLEARNING')
#       7 # Now import the module
# ----> 8 from classs import NN_model
#
# ImportError: cannot import name 'NN_model' from 'classs' (C:\Users\LENOVO\Desktop\desktop docs\SUPERVISEDLEARNING\classs.py)
